# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Earthquake That Potentially Trigger Volcanic Eruption Prediction
#
# ## Data Preprocessing
#
# The main idea of this project is to predict wether or not an earthquake would trigger volcanic eruptioin.<br/>
# <br/>
# To do this I picked two datasets from kaggle.com, which are:
# 1. #### [Significant Earthquakes, 1965-2016](https://www.kaggle.com/usgs/earthquake-database) <br/>
# Consists Date, time, and location of all earthquakes around the world with magnitude of 5.5 or higher. <br/>
# 2. #### [Volcanic Eruptions in the Holocene Period](https://www.kaggle.com/smithsonian/volcanic-eruptions) <br/>
# Consists Name, location, and type of volcanoes active in the past 10,000 years.<br/>

# %% [markdown]
# ### Importing, Reading, Cleaning, and Tidying Dataset
# Since I've used two datasets, I think it's best to do this step one by one. In this part we are going to read and understand each columns in both datasets, check errors and missing values, and decide which columns should be used in this project.

# %%
# Importing both dataset
eq = pd. read_csv('./data/earthquake.csv')
ve = pd.read_csv('./data/volcanic_eruption.csv')

# %% [markdown]
# ###  1 Significant Earthquakes, 1965-2016
# All of the column description can be accessed from:<br/>
# https://earthquake.usgs.gov/data/comcat/data-eventterms.php<br/>
# <br/>
# Column Description:
# 1. <b>Date</b> : Date when the event occurred.
# 2. <b>Time</b> : Time when the event occurred.
# 3. <b>Latitude</b> : Decimal degrees latitude.
# 4. <b>Longitude</b> : Decimal degrees longitude.
# 5. <b>Type</b> : Type of seismic event. ('Earthquake','Nuclear Explosion', 'Explosion', 'Rock Burst')
# 6. <b>Depth</b> : Depth of the event in kilometers.
# 7. <b>Depth Error</b> : Uncertainty of reported depth of the event in kilometers.
# 8. <b>Depth Seismic Stations</b> : The total number of seismic stations used to determine earthquake location.
# 9. <b>Magnitude</b> : The magnitude for the event.
# 10. <b>Magnitude Type</b> : The method or algorithm used to calculate the preferred magnitude for the event.
# 11. <b>Magnitude Error</b> : Uncertainty of reported magnitude of the event. The estimated standard error of the magnitude. The uncertainty corresponds to the specific magnitude type being reported and does not take into account magnitude variations and biases between different magnitude scales.
# 12. <b>Magnitude Seismic Stations</b> : The total number of seismic stations used to calculate the magnitude for this earthquake.
# 13. <b>Azimuthal Gap</b> : The largest azimuthal gap between azimuthally adjacent stations (in degrees). In general, the smaller this number, the more reliable is the calculated horizontal position of the earthquake. Earthquake locations in which the azimuthal gap exceeds 180 degrees typically have large location and depth uncertainties.
# 14. <b>Horizontal Distance</b> : Horizontal distance from the epicenter to the nearest station (in degrees). 1 degree is approximately 111.2 kilometers. In general, the smaller this number, the more reliable is the calculated depth of the earthquake.
# 15. <b>Horizontal Error</b> : Uncertainty of reported location of the event in kilometers.
# 16. <b>Root Mean Square</b> : The root-mean-square (RMS) travel time residual, in sec, using all weights. This parameter provides a measure of the fit of the observed arrival times to the predicted arrival times for this location. Smaller numbers reflect a better fit of the data. The value is dependent on the accuracy of the velocity model used to compute the earthquake location, the quality weights assigned to the arrival time data, and the procedure used to locate the earthquake.<br/>
# 17. <b>ID</b> : A unique identifier for the event.
# 18. <b>Source</b> : list of network contributors.
# 19. <b>Location Source</b> : Network that originally authored the reported location of this event.
# 20. <b>Magnitude Source</b> : Network that originally authored the reported magnitude for this event.
# 21. <b>Status</b> : Indicates whether the event has been reviewed by a human.

# %%
eq.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  Magnitude Error  \
# 0                     NaN        6.0             MW              NaN
# 1                     NaN        5.8             MW              NaN
# 2                     NaN        6.2             MW              NaN
# 3                     NaN        5.8             MW              NaN
# 4                     NaN        5.8             MW              NaN
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 2                         NaN            NaN                  NaN
# 3                         NaN            NaN                  NaN
# 4                         NaN            NaN                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 0               NaN               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1               NaN               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 2               NaN               NaN  ISCGEM860762  ISCGEM          ISCGEM
# 3               NaN               NaN  ISCGEM860856  ISCGEM          ISCGEM
# 4               NaN               NaN  ISCGEM860890  ISCGEM          ISCGEM
#
#   Magnitude Source     Status
# 0           ISCGEM  Automatic
# 1           ISCGEM  Automatic
# 2           ISCGEM  Automatic
# 3           ISCGEM  Automatic
# 4           ISCGEM  Automatic

# %%
eq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        23412 non-null  object
#  1   Time                        23412 non-null  object
#  2   Latitude                    23412 non-null  float64
#  3   Longitude                   23412 non-null  float64
#  4   Type                        23412 non-null  object
#  5   Depth                       23412 non-null  float64
#  6   Depth Error                 4461 non-null   float64
#  7   Depth Seismic Stations      7097 non-null   float64
#  8   Magnitude                   23412 non-null  float64
#  9   Magnitude Type              23409 non-null  object
#  10  Magnitude Error             327 non-null    float64
#  11  Magnitude Seismic Stations  2564 non-null   float64
#  12  Azimuthal Gap               7299 non-null   float64
#  13  Horizontal Distance         1604 non-null   float64
#  14  Horizontal Error            1156 non-null   float64
#  15  Root Mean Square            17352 non-null  float64
#  16  ID                          23412 non-null  object
#  17  Source                      23412 non-null  object
#  18  Location Source             23412 non-null  object
#  19  Magnitude Source            23412 non-null  object
#  20  Status                      23412 non-null  object
# dtypes: float64(12), object(9)
# memory usage: 3.8+ MB

# %% [markdown]
# ##### Parsing Dates
# The first thing I've noticed is the 'Date' and 'Time' columns in string format. we should start by combining this two columns and parse it to datetime format.<br/>
# Although it should be noted that a small portion of the data is written in different style that need a different care. to find this we search for 'Date' values with more than 10 character.

# %%
eq[eq['Date'].str.len() > 10]
# Out:
#                            Date                      Time  Latitude  \
# 3378   1975-02-23T02:58:41.000Z  1975-02-23T02:58:41.000Z     8.017
# 7512   1985-04-28T02:53:41.530Z  1985-04-28T02:53:41.530Z   -32.998
# 20650  2011-03-13T02:23:34.520Z  2011-03-13T02:23:34.520Z    36.344
#
#        Longitude        Type  Depth  Depth Error  Depth Seismic Stations  \
# 3378     124.075  Earthquake  623.0          NaN                     NaN
# 7512     -71.766  Earthquake   33.0          NaN                     NaN
# 20650    142.344  Earthquake   10.1         13.9                   289.0
#
#        Magnitude Magnitude Type  Magnitude Error  Magnitude Seismic Stations  \
# 3378         5.6             MB              NaN                         NaN
# 7512         5.6             MW              NaN                         NaN
# 20650        5.8            MWC              NaN                         NaN
#
#        Azimuthal Gap  Horizontal Distance  Horizontal Error  Root Mean Square  \
# 3378             NaN                  NaN               NaN               NaN
# 7512             NaN                  NaN               NaN              1.30
# 20650           32.3                  NaN               NaN              1.06
#
#                ID Source Location Source Magnitude Source    Status
# 3378   USP0000A09     US              US               US  Reviewed
# 7512   USP0002E81     US              US              HRV  Reviewed
# 20650  USP000HWQP     US              US             GCMT  Reviewed

# %%
# now that we get the error index, we could use iloc to slice it
eq.Date.iloc[[3378,7512,20650]] = eq.Date.str[:10]
eq.Time.iloc[[3378,7512,20650]] = eq.Time.str[12:20]
# Out:
# C:\Users\adinatha\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
# and then combine both columns and convert it to datetime format.
eq['Date_Time'] = eq['Date'] + ' ' + eq['Time']
eq['Date_Time'] = pd.to_datetime(eq['Date_Time'])

# %%
eq.iloc[[3378,7512,20650]]
# Out:
#              Date      Time  Latitude  Longitude        Type  Depth  \
# 3378   1975-02-23  2:58:41.     8.017    124.075  Earthquake  623.0
# 7512   1985-04-28  2:53:41.   -32.998    -71.766  Earthquake   33.0
# 20650  2011-03-13  2:23:34.    36.344    142.344  Earthquake   10.1
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# 3378           NaN                     NaN        5.6             MB
# 7512           NaN                     NaN        5.6             MW
# 20650         13.9                   289.0        5.8            MWC
#
#        Magnitude Error  Magnitude Seismic Stations  Azimuthal Gap  \
# 3378               NaN                         NaN            NaN
# 7512               NaN                         NaN            NaN
# 20650              NaN                         NaN           32.3
#
#        Horizontal Distance  Horizontal Error  Root Mean Square          ID  \
# 3378                   NaN               NaN               NaN  USP0000A09
# 7512                   NaN               NaN              1.30  USP0002E81
# 20650                  NaN               NaN              1.06  USP000HWQP
#
#       Source Location Source Magnitude Source    Status           Date_Time
# 3378      US              US               US  Reviewed 1975-02-23 02:58:41
# 7512      US              US              HRV  Reviewed 1985-04-28 02:53:41
# 20650     US              US             GCMT  Reviewed 2011-03-13 02:23:34

# %%
# now it should be safe to remove both 'Date' and 'Time' columns
eq = eq.drop(['Date','Time'],axis = 1)

# %%
cols = eq.columns.tolist()
cols = cols[-1:] + cols[:-1]
cols
# Out:
# ['Date_Time',
#  'Latitude',
#  'Longitude',
#  'Type',
#  'Depth',
#  'Depth Error',
#  'Depth Seismic Stations',
#  'Magnitude',
#  'Magnitude Type',
#  'Magnitude Error',
#  'Magnitude Seismic Stations',
#  'Azimuthal Gap',
#  'Horizontal Distance',
#  'Horizontal Error',
#  'Root Mean Square',
#  'ID',
#  'Source',
#  'Location Source',
#  'Magnitude Source',
#  'Status']

# %%
eq = eq[cols]
eq.head()
# Out:
#             Date_Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0 1965-01-02 13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1 1965-01-04 11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2 1965-01-05 18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3 1965-01-08 18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4 1965-01-09 13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  Magnitude Error  \
# 0                     NaN        6.0             MW              NaN
# 1                     NaN        5.8             MW              NaN
# 2                     NaN        6.2             MW              NaN
# 3                     NaN        5.8             MW              NaN
# 4                     NaN        5.8             MW              NaN
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 2                         NaN            NaN                  NaN
# 3                         NaN            NaN                  NaN
# 4                         NaN            NaN                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 0               NaN               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1               NaN               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 2               NaN               NaN  ISCGEM860762  ISCGEM          ISCGEM
# 3               NaN               NaN  ISCGEM860856  ISCGEM          ISCGEM
# 4               NaN               NaN  ISCGEM860890  ISCGEM          ISCGEM
#
#   Magnitude Source     Status
# 0           ISCGEM  Automatic
# 1           ISCGEM  Automatic
# 2           ISCGEM  Automatic
# 3           ISCGEM  Automatic
# 4           ISCGEM  Automatic

# %%
eq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date_Time                   23412 non-null  datetime64[ns]
#  1   Latitude                    23412 non-null  float64
#  2   Longitude                   23412 non-null  float64
#  3   Type                        23412 non-null  object
#  4   Depth                       23412 non-null  float64
#  5   Depth Error                 4461 non-null   float64
#  6   Depth Seismic Stations      7097 non-null   float64
#  7   Magnitude                   23412 non-null  float64
#  8   Magnitude Type              23409 non-null  object
#  9   Magnitude Error             327 non-null    float64
#  10  Magnitude Seismic Stations  2564 non-null   float64
#  11  Azimuthal Gap               7299 non-null   float64
#  12  Horizontal Distance         1604 non-null   float64
#  13  Horizontal Error            1156 non-null   float64
#  14  Root Mean Square            17352 non-null  float64
#  15  ID                          23412 non-null  object
#  16  Source                      23412 non-null  object
#  17  Location Source             23412 non-null  object
#  18  Magnitude Source            23412 non-null  object
#  19  Status                      23412 non-null  object
# dtypes: datetime64[ns](1), float64(12), object(7)
# memory usage: 3.6+ MB

# %% [markdown]
# ##### Dropping Columns and Values
# There are several things that needs to be considered in terms of dropping columns and values.
# 1. From 'Type' Columns, Since the target of this project is related to volcanic activities, it is safe to drop the earthquakes with Nuclear explosions, Rock Burst, and Explosion Type.
# 2. 'Depth Error' and 'Magnitude Error' columns is the uncertainity value of the earthquakes features, however I did not have a certain idea about treating this data given there are no specific explaination about it. Therefore, it is considerable to drop them.
# 3. The same goes for Depth and Magnitude Seismic Stations.
# 4. In 'Azimuthal Gap' and 'Horizontal Distance' columns, the smaller the number tend to have a more reliable data. however while I've checked the high number of both columns. the 'Status' column shows that it has been reviewed by human expertise.

# %%
# filter the dataset by type
eq = eq[eq['Type'] == 'Earthquake']

# %%
# use only relevant columns for this project
eq = eq[['Date_Time','Latitude','Longitude','Depth','Magnitude','Magnitude Type']]

# %%
eq.reset_index(inplace = True)

# %%
# notice that there are missing values on Magnitude type
eq = eq.drop('index',axis = 1)
eq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23232 entries, 0 to 23231
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date_Time       23232 non-null  datetime64[ns]
#  1   Latitude        23232 non-null  float64
#  2   Longitude       23232 non-null  float64
#  3   Depth           23232 non-null  float64
#  4   Magnitude       23232 non-null  float64
#  5   Magnitude Type  23229 non-null  object
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 1.1+ MB

# %%
eq[eq['Magnitude Type'].isna() == True]
# Out:
#                Date_Time  Latitude  Longitude  Depth  Magnitude Magnitude Type
# 6598 1983-08-24 13:36:00   40.3732  -124.9227  11.93       5.70            NaN
# 7172 1984-11-23 18:08:00   37.4600  -118.5900   9.00       5.82            NaN
# 7786 1986-03-31 11:55:00   37.4788  -121.6858   9.17       5.60            NaN

# %% [markdown]
# <b>Dealing Missing Values</b><br/>
# since there are only three missing values, we could determine the Magnitude Type based on the Depth and Magnitude Feature and fill them with the mode of the relatively similar data. The results is most likely suitable for MWW types.

# %%
eq_nan_a = eq.loc[((eq['Depth'].values < 9.5) & (eq['Depth'].values >= 9) & (eq['Magnitude'].values <= 5.9) & (eq['Magnitude'].values >= 5.6))]

# %%
eq_nan_a['Magnitude Type'].mode()
# Out:
# 0    MWW
# dtype: object

# %%
eq_nan_b = eq.loc[((eq['Depth'].values < 12.5) & (eq['Depth'].values >= 11.5) & (eq['Magnitude'].values <= 5.8) & (eq['Magnitude'].values >= 5.6))]

# %%
eq_nan_b['Magnitude Type'].mode()
# Out:
# 0    MWW
# dtype: object

# %%
eq['Magnitude Type'] = eq['Magnitude Type'].fillna('MWW')

# %%
eq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23232 entries, 0 to 23231
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date_Time       23232 non-null  datetime64[ns]
#  1   Latitude        23232 non-null  float64
#  2   Longitude       23232 non-null  float64
#  3   Depth           23232 non-null  float64
#  4   Magnitude       23232 non-null  float64
#  5   Magnitude Type  23232 non-null  object
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 1.1+ MB

# %%
eq.to_csv('./data/clean_earthquake.csv', index = False)

# %% [markdown]
# ###  2 Volcanic Eruptions in the Holocene Period
#
# Column Description:
# 1. <b>Number</b> : Unique ID for each Volcano.
# 2. <b>Name</b> : Name of the Volcano.
# 3. <b>Country</b> : The Country where the volcano located.
# 4. <b>Region</b> : The Region where the volcano located.
# 5. <b>Type</b> : Types of the volcano.
# 6. <b>Activity Evidence</b> : Evidences of eruption activity.
# 7. <b>Last Known Eruption</b> : The year which the latest eruption activity occured.
# 8. <b>Latitude</b> : Decimal degree latitudes.
# 9. <b>Longitude</b> : Decimal degree longitude.
# 10. <b>Elevation (Meters)</b> : Elevation of the volcano.
# 11. <b>Dominant Rock Type</b> : The volcano major rock type variations.
# 12. <b>Tectonic Setting</b> : The tectonic setting where the eruption activity occured.

# %%
ve.head()
# Out:
#    Number                       Name  Country                          Region  \
# 0  210010  West Eifel Volcanic Field  Germany  Mediterranean and Western Asia
# 1  210020            Chaine des Puys   France  Mediterranean and Western Asia
# 2  210030        Olot Volcanic Field    Spain  Mediterranean and Western Asia
# 3  210040   Calatrava Volcanic Field    Spain  Mediterranean and Western Asia
# 4  211001                 Larderello    Italy  Mediterranean and Western Asia
#
#                   Type  Activity Evidence Last Known Eruption  Latitude  \
# 0              Maar(s)     Eruption Dated            8300 BCE    50.170
# 1         Lava dome(s)     Eruption Dated            4040 BCE    45.775
# 2  Pyroclastic cone(s)  Evidence Credible             Unknown    42.170
# 3  Pyroclastic cone(s)     Eruption Dated            3600 BCE    38.870
# 4  Explosion crater(s)  Eruption Observed             1282 CE    43.250
#
#    Longitude  Elevation (Meters)                Dominant Rock Type  \
# 0       6.85                 600                           Foidite
# 1       2.97                1464             Basalt / Picro-Basalt
# 2       2.53                 893  Trachybasalt / Tephrite Basanite
# 3      -4.02                1117             Basalt / Picro-Basalt
# 4      10.87                 500                           No Data
#
#                                Tectonic Setting
# 0        Rift Zone / Continental Crust (>25 km)
# 1        Rift Zone / Continental Crust (>25 km)
# 2       Intraplate / Continental Crust (>25 km)
# 3       Intraplate / Continental Crust (>25 km)
# 4  Subduction Zone / Continental Crust (>25 km)

# %%
ve.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1508 entries, 0 to 1507
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Number               1508 non-null   int64
#  1   Name                 1508 non-null   object
#  2   Country              1508 non-null   object
#  3   Region               1508 non-null   object
#  4   Type                 1508 non-null   object
#  5   Activity Evidence    1507 non-null   object
#  6   Last Known Eruption  1508 non-null   object
#  7   Latitude             1508 non-null   float64
#  8   Longitude            1508 non-null   float64
#  9   Elevation (Meters)   1508 non-null   int64
#  10  Dominant Rock Type   1455 non-null   object
#  11  Tectonic Setting     1501 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 141.5+ KB

# %%
# Since our earthquake dataset is limited t0 1965 - 2016 CE, we're going to drop eruption that happened before it.
ve.drop(ve[ve['Last Known Eruption'].str.contains('BCE')].index,inplace =True)

# %%
ve.drop(ve[ve['Last Known Eruption'].str.contains('Unknown')].index,inplace = True)

# %%
ve['Last Known Eruption'] = ve['Last Known Eruption'].str.replace(' CE','')

# %%
ve['Last Known Eruption'] = pd.to_numeric(ve['Last Known Eruption'])

# %%
index = ve.loc[((ve['Last Known Eruption'].values <= 2016) & (ve['Last Known Eruption'].values >= 1965))].index
index
# Out:
# Int64Index([  11,   15,   44,   45,   50,   52,   54,   58,   68,   70,
#             ...
#             1465, 1470, 1472, 1481, 1491, 1496, 1497, 1498, 1499, 1503],
#            dtype='int64', length=324)

# %%
ve = ve.loc[index]

# %%
ve.reset_index(inplace = True)
ve.drop('index',axis = 1,inplace = True)

# %%
# There are still missing values in 'Activity Evidence' and 'Dominant Rock Type'.
ve.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Number               324 non-null    int64
#  1   Name                 324 non-null    object
#  2   Country              324 non-null    object
#  3   Region               324 non-null    object
#  4   Type                 324 non-null    object
#  5   Activity Evidence    323 non-null    object
#  6   Last Known Eruption  324 non-null    int64
#  7   Latitude             324 non-null    float64
#  8   Longitude            324 non-null    float64
#  9   Elevation (Meters)   324 non-null    int64
#  10  Dominant Rock Type   322 non-null    object
#  11  Tectonic Setting     324 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 30.5+ KB

# %%
ve[ve['Activity Evidence'].isna()==True]
# Out:
#      Number                                Name        Country  \
# 162  284305  Mariana Back-Arc Segment at 15.5°N  United States
#
#                       Region       Type Activity Evidence  \
# 162  Japan, Taiwan, Marianas  Submarine               NaN
#
#      Last Known Eruption  Latitude  Longitude  Elevation (Meters)  \
# 162                 2015    15.406    144.506               -4100
#
#     Dominant Rock Type                           Tectonic Setting
# 162                NaN  Subduction Zone / Oceanic Crust (< 15 km)

# %%
#as for Activity Evidences, would not really be useful for this project, we could fill it with the mode for the time being.
ve['Activity Evidence'] = ve['Activity Evidence'].fillna(ve['Activity Evidence'].mode()[0])

# %%
# in Dominant Rock Type, there ara missing values stored as 'No Data'
# we need to replace this with NaN.
ve[ve['Dominant Rock Type'] == 'No Data']
# Out:
#      Number                       Name            Country  \
# 4    221041                     Dallol           Ethiopia
# 29   243030                    Unnamed              Tonga
# 40   250030                    Unnamed   Papua New Guinea
# 158  284193     South Sarigan Seamount      United States
# 173  290160                    Unnamed             Russia
# 294  358059                   Arenales              Chile
# 310  377020  East Gakkel Ridge at 85°E  Undersea Features
# 315  385052                    Unnamed  Undersea Features
#
#                        Region                 Type  Activity Evidence  \
# 4          Africa and Red Sea  Explosion crater(s)  Eruption Observed
# 29        New Zealand to Fiji            Submarine  Eruption Observed
# 40    Melanesia and Australia            Submarine     Eruption Dated
# 158   Japan, Taiwan, Marianas            Submarine  Eruption Observed
# 173             Kuril Islands            Submarine     Eruption Dated
# 294             South America        Stratovolcano  Eruption Observed
# 310  Iceland and Arctic Ocean            Submarine  Evidence Credible
# 315            Atlantic Ocean            Submarine  Eruption Observed
#
#      Last Known Eruption  Latitude  Longitude  Elevation (Meters)  \
# 4                   2011    14.242      40.30                 -48
# 29                  1999   -20.850    -175.53                 -13
# 40                  1972    -3.030     147.78               -1300
# 158                 2010    16.580     145.78                -184
# 173                 1972    46.470     151.28                -502
# 294                 1979   -47.200     -73.48                3437
# 310                 1999    85.608      85.25               -3800
# 315                 2002   -32.958      -5.22                   0
#
#     Dominant Rock Type                              Tectonic Setting
# 4              No Data     Rift Zone / Intermediate Crust (15-25 km)
# 29             No Data     Subduction Zone / Oceanic Crust (< 15 km)
# 40             No Data        Rift Zone / Continental Crust (>25 km)
# 158            No Data     Subduction Zone / Crust Thickness Unknown
# 173            No Data     Subduction Zone / Oceanic Crust (< 15 km)
# 294            No Data  Subduction Zone / Continental Crust (>25 km)
# 310            No Data           Rift Zone / Oceanic Crust (< 15 km)
# 315            No Data          Intraplate / Oceanic Crust (< 15 km)

# %%
ve['Dominant Rock Type'] = ve['Dominant Rock Type'].replace('No Data',np.nan)

# %%
ve[ve['Dominant Rock Type'].isna()==True]
# Out:
#      Number                                Name            Country  \
# 4    221041                              Dallol           Ethiopia
# 26   242005                      Havre Seamount        New Zealand
# 29   243030                             Unnamed              Tonga
# 40   250030                             Unnamed   Papua New Guinea
# 158  284193              South Sarigan Seamount      United States
# 162  284305  Mariana Back-Arc Segment at 15.5°N      United States
# 173  290160                             Unnamed             Russia
# 294  358059                            Arenales              Chile
# 310  377020           East Gakkel Ridge at 85°E  Undersea Features
# 315  385052                             Unnamed  Undersea Features
#
#                        Region                 Type  Activity Evidence  \
# 4          Africa and Red Sea  Explosion crater(s)  Eruption Observed
# 26        New Zealand to Fiji            Submarine  Eruption Observed
# 29        New Zealand to Fiji            Submarine  Eruption Observed
# 40    Melanesia and Australia            Submarine     Eruption Dated
# 158   Japan, Taiwan, Marianas            Submarine  Eruption Observed
# 162   Japan, Taiwan, Marianas            Submarine  Eruption Observed
# 173             Kuril Islands            Submarine     Eruption Dated
# 294             South America        Stratovolcano  Eruption Observed
# 310  Iceland and Arctic Ocean            Submarine  Evidence Credible
# 315            Atlantic Ocean            Submarine  Eruption Observed
#
#      Last Known Eruption  Latitude  Longitude  Elevation (Meters)  \
# 4                   2011    14.242     40.300                 -48
# 26                  2012   -31.080   -179.033                -897
# 29                  1999   -20.850   -175.530                 -13
# 40                  1972    -3.030    147.780               -1300
# 158                 2010    16.580    145.780                -184
# 162                 2015    15.406    144.506               -4100
# 173                 1972    46.470    151.280                -502
# 294                 1979   -47.200    -73.480                3437
# 310                 1999    85.608     85.250               -3800
# 315                 2002   -32.958     -5.220                   0
#
#     Dominant Rock Type                              Tectonic Setting
# 4                  NaN     Rift Zone / Intermediate Crust (15-25 km)
# 26                 NaN     Subduction Zone / Oceanic Crust (< 15 km)
# 29                 NaN     Subduction Zone / Oceanic Crust (< 15 km)
# 40                 NaN        Rift Zone / Continental Crust (>25 km)
# 158                NaN     Subduction Zone / Crust Thickness Unknown
# 162                NaN     Subduction Zone / Oceanic Crust (< 15 km)
# 173                NaN     Subduction Zone / Oceanic Crust (< 15 km)
# 294                NaN  Subduction Zone / Continental Crust (>25 km)
# 310                NaN           Rift Zone / Oceanic Crust (< 15 km)
# 315                NaN          Intraplate / Oceanic Crust (< 15 km)

# %%
# try to get similarities in the rest of the dataset, we could see by its coordinate that it is closer to Lautaro Mountain.
# therefore we could fill the Arenales' Dominant Rock Type as 'Dacite'
ve.loc[((ve['Type'] == 'Stratovolcano') & (ve['Tectonic Setting'] == 'Subduction Zone / Continental Crust (>25 km)') & (ve['Country'] == 'Chile'))]
# Out:
#      Number                   Name Country         Region           Type  \
# 282  357060            Azul, Cerro   Chile  South America  Stratovolcano
# 283  357070    Chillan, Nevados de   Chile  South America  Stratovolcano
# 285  357091               Callaqui   Chile  South America  Stratovolcano
# 286  357100              Lonquimay   Chile  South America  Stratovolcano
# 287  357110                 Llaima   Chile  South America  Stratovolcano
# 288  357120             Villarrica   Chile  South America  Stratovolcano
# 290  357150  Puyehue-Cordon Caulle   Chile  South America  Stratovolcano
# 291  358020                Calbuco   Chile  South America  Stratovolcano
# 293  358057          Hudson, Cerro   Chile  South America  Stratovolcano
# 294  358059               Arenales   Chile  South America  Stratovolcano
# 295  358060                Lautaro   Chile  South America  Stratovolcano
#
#      Activity Evidence  Last Known Eruption  Latitude  Longitude  \
# 282  Eruption Observed                 1967   -35.653    -70.761
# 283  Eruption Observed                 2016   -36.863    -71.377
# 285  Eruption Observed                 1980   -37.920    -71.450
# 286  Eruption Observed                 1990   -38.379    -71.586
# 287  Eruption Observed                 2009   -38.692    -71.729
# 288  Eruption Observed                 2016   -39.420    -71.930
# 290  Eruption Observed                 2012   -40.590    -72.117
# 291  Eruption Observed                 2015   -41.330    -72.618
# 293  Eruption Observed                 2011   -45.900    -72.970
# 294  Eruption Observed                 1979   -47.200    -73.480
# 295  Eruption Observed                 1979   -49.020    -73.550
#
#      Elevation (Meters)            Dominant Rock Type  \
# 282                3788                        Dacite
# 283                3212  Andesite / Basaltic Andesite
# 285                3164  Andesite / Basaltic Andesite
# 286                2832  Andesite / Basaltic Andesite
# 287                3125         Basalt / Picro-Basalt
# 288                2847         Basalt / Picro-Basalt
# 290                2236  Andesite / Basaltic Andesite
# 291                1974  Andesite / Basaltic Andesite
# 293                1905         Basalt / Picro-Basalt
# 294                3437                           NaN
# 295                3607                        Dacite
#
#                                  Tectonic Setting
# 282  Subduction Zone / Continental Crust (>25 km)
# 283  Subduction Zone / Continental Crust (>25 km)
# 285  Subduction Zone / Continental Crust (>25 km)
# 286  Subduction Zone / Continental Crust (>25 km)
# 287  Subduction Zone / Continental Crust (>25 km)
# 288  Subduction Zone / Continental Crust (>25 km)
# 290  Subduction Zone / Continental Crust (>25 km)
# 291  Subduction Zone / Continental Crust (>25 km)
# 293  Subduction Zone / Continental Crust (>25 km)
# 294  Subduction Zone / Continental Crust (>25 km)
# 295  Subduction Zone / Continental Crust (>25 km)

# %%
ve['Dominant Rock Type'].loc[294] = 'Dacite'
# Out:
# C:\Users\adinatha\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
# for the missing 'Dominant Rock Type' that have a Submarine Type, we could safely assume that it was a basaltic rock types.


# since the Dallol volcano doesn't have a lot of similarities we use the tectonic settings and use the mode of the Dominant Rock Types
# which is 'Basalt / Picro-Basalt'

ve.loc[(ve['Tectonic Setting'] == 'Rift Zone / Intermediate Crust (15-25 km)')]
# Out:
#     Number           Name   Country              Region                 Type  \
# 4   221041         Dallol  Ethiopia  Africa and Red Sea  Explosion crater(s)
# 5   221060  Alu-Dalafilla  Ethiopia  Africa and Red Sea      Fissure vent(s)
# 6   221080       Erta Ale  Ethiopia  Africa and Red Sea               Shield
# 7   221101          Nabro   Eritrea  Africa and Red Sea        Stratovolcano
# 8   221113        Dabbahu  Ethiopia  Africa and Red Sea        Stratovolcano
# 9   221115   Manda Hararo  Ethiopia  Africa and Red Sea            Shield(s)
# 10  221126      Ardoukoba  Djibouti  Africa and Red Sea      Fissure vent(s)
#
#     Activity Evidence  Last Known Eruption  Latitude  Longitude  \
# 4   Eruption Observed                 2011    14.242     40.300
# 5   Eruption Observed                 2008    13.793     40.553
# 6   Eruption Observed                 2016    13.600     40.670
# 7   Eruption Observed                 2012    13.370     41.700
# 8   Eruption Observed                 2005    12.595     40.480
# 9   Eruption Observed                 2009    12.170     40.820
# 10  Eruption Observed                 1978    11.580     42.470
#
#     Elevation (Meters)       Dominant Rock Type  \
# 4                  -48                      NaN
# 5                  578    Basalt / Picro-Basalt
# 6                  613    Basalt / Picro-Basalt
# 7                 2218  Trachyte / Trachydacite
# 8                 1401    Basalt / Picro-Basalt
# 9                  600    Basalt / Picro-Basalt
# 10                 298    Basalt / Picro-Basalt
#
#                              Tectonic Setting
# 4   Rift Zone / Intermediate Crust (15-25 km)
# 5   Rift Zone / Intermediate Crust (15-25 km)
# 6   Rift Zone / Intermediate Crust (15-25 km)
# 7   Rift Zone / Intermediate Crust (15-25 km)
# 8   Rift Zone / Intermediate Crust (15-25 km)
# 9   Rift Zone / Intermediate Crust (15-25 km)
# 10  Rift Zone / Intermediate Crust (15-25 km)

# %%
ve['Dominant Rock Type'] = ve['Dominant Rock Type'].fillna('Basalt / Picro-Basalt')

# %%
ve.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Number               324 non-null    int64
#  1   Name                 324 non-null    object
#  2   Country              324 non-null    object
#  3   Region               324 non-null    object
#  4   Type                 324 non-null    object
#  5   Activity Evidence    324 non-null    object
#  6   Last Known Eruption  324 non-null    int64
#  7   Latitude             324 non-null    float64
#  8   Longitude            324 non-null    float64
#  9   Elevation (Meters)   324 non-null    int64
#  10  Dominant Rock Type   324 non-null    object
#  11  Tectonic Setting     324 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 30.5+ KB

# %%
ve.describe()
# Out:
#               Number  Last Known Eruption    Latitude   Longitude  \
# count     324.000000           324.000000  324.000000  324.000000
# mean   297801.348765          2001.762346   10.174343   27.024312
# std     45200.358060            15.021419   31.342992  121.486938
# min    211040.000000          1966.000000  -77.530000 -179.033000
# 25%    263307.500000          1992.000000   -8.442000  -84.858250
# 50%    284258.000000          2008.000000   10.306000   81.537500
# 75%    342042.500000          2015.000000   36.459000  139.950750
# max    390130.000000          2016.000000   85.608000  179.580000
#
#        Elevation (Meters)
# count          324.000000
# mean          1542.472222
# std           1609.867361
# min          -4100.000000
# 25%            634.500000
# 50%           1484.500000
# 75%           2428.250000
# max           5967.000000

# %%
ve.to_csv('./data/clean_volcanic_eruption.csv', index = False)

# %% [markdown]
# ## Create New Dataset
# Now that we have got both datasets cleaned, we should create a new dataset with the nearest volcanic eruption from the earthquake location and its distances in the cleaned earthquake dataset and merge it with cleaned volcanic dataset.

# %%
clean_eq = pd. read_csv('./data/clean_earthquake.csv')
clean_ve = pd.read_csv('./data/clean_volcanic_eruption.csv')

# %% [markdown]
# ### Getting nearest eruption
# To get the nearest eruption we use cdist from scipy.spatial.distance and get the names of the nearest volcano.<br/>
# <br/>
# [source](https://stackoverflow.com/a/39318808)

# %%
# create new dataframes so the main dataframe doesn't messed up through the process.
nv_eq = clean_eq[['Latitude','Longitude']]
nv_ve = clean_ve[['Latitude','Longitude','Name']]

# generate list of tuples including lat and lon at both dataset where x is lat and y is lon.
nv_eq['points_eq'] = [(x, y) for x,y in zip(nv_eq['Latitude'], nv_eq['Longitude'])]
nv_ve['points_ve'] = [(x, y) for x,y in zip(nv_ve['Latitude'], nv_ve['Longitude'])]

# import cdist
from scipy.spatial.distance import cdist

# find nearest eruption from earthquakes
nv_eq['near_volcano_points'] = [list(nv_ve['points_ve'])[cdist([x], list(nv_ve['points_ve'])).argmin()] for x in nv_eq['points_eq']]

# match coordinates points with volcano's name
nv_eq['near_volcano_names'] = [nv_ve[nv_ve['points_ve'] == x]['Name'].values[0] for x in nv_eq['near_volcano_points']]
# Out:
# C:\Users\adinatha\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\adinatha\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\adinatha\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\adinatha\anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
# append the near volcano names to the main dataframes
clean_eq['Nearest Volcano'] = nv_eq['near_volcano_names']

# %%
clean_eq.head()
# Out:
#              Date_Time  Latitude  Longitude  Depth  Magnitude Magnitude Type  \
# 0  1965-01-02 13:44:18    19.246    145.616  131.6        6.0             MW
# 1  1965-01-04 11:29:49     1.863    127.352   80.0        5.8             MW
# 2  1965-01-05 18:05:58   -20.579   -173.972   20.0        6.2             MW
# 3  1965-01-08 18:49:43   -59.076    -23.557   15.0        5.8             MW
# 4  1965-01-09 13:32:50    11.938    126.427   15.0        5.8             MW
#
#   Nearest Volcano
# 0     Supply Reef
# 1             Ibu
# 2           Tofua
# 3  Montagu Island
# 4         Bulusan

# %% [markdown]
# ### Merge Dataset
# merge both datasets on Volcano names, both columns in dataset should have same name.

# %%
clean_ve =clean_ve.rename(columns = {'Name' : 'Nearest Volcano'})
clean_ve.head()
# Out:
#    Number Nearest Volcano   Country                          Region  \
# 0  211040       Stromboli     Italy  Mediterranean and Western Asia
# 1  211060            Etna     Italy  Mediterranean and Western Asia
# 2  221010  Tair, Jebel at     Yemen              Africa and Red Sea
# 3  221020    Zubair Group     Yemen              Africa and Red Sea
# 4  221041          Dallol  Ethiopia              Africa and Red Sea
#
#                   Type  Activity Evidence  Last Known Eruption  Latitude  \
# 0        Stratovolcano  Eruption Observed                 2016    38.789
# 1    Stratovolcano(es)  Eruption Observed                 2016    37.734
# 2        Stratovolcano  Eruption Observed                 2008    15.550
# 3               Shield  Eruption Observed                 2013    15.050
# 4  Explosion crater(s)  Eruption Observed                 2011    14.242
#
#    Longitude  Elevation (Meters)                        Dominant Rock Type  \
# 0     15.213                 924  Trachyandesite / Basaltic Trachyandesite
# 1     15.004                3330          Trachybasalt / Tephrite Basanite
# 2     41.830                 244          Trachybasalt / Tephrite Basanite
# 3     42.180                 191                     Basalt / Picro-Basalt
# 4     40.300                 -48                     Basalt / Picro-Basalt
#
#                                Tectonic Setting
# 0  Subduction Zone / Continental Crust (>25 km)
# 1  Subduction Zone / Continental Crust (>25 km)
# 2           Rift Zone / Oceanic Crust (< 15 km)
# 3           Rift Zone / Oceanic Crust (< 15 km)
# 4     Rift Zone / Intermediate Crust (15-25 km)

# %%
main_df = pd.merge(clean_eq, clean_ve, how = 'left', on = 'Nearest Volcano')

# %%
main_df.head()
# Out:
#              Date_Time  Latitude_x  Longitude_x  Depth  Magnitude  \
# 0  1965-01-02 13:44:18      19.246      145.616  131.6        6.0
# 1  1965-01-04 11:29:49       1.863      127.352   80.0        5.8
# 2  1965-01-05 18:05:58     -20.579     -173.972   20.0        6.2
# 3  1965-01-08 18:49:43     -59.076      -23.557   15.0        5.8
# 4  1965-01-09 13:32:50      11.938      126.427   15.0        5.8
#
#   Magnitude Type Nearest Volcano  Number         Country  \
# 0             MW     Supply Reef  284142   United States
# 1             MW             Ibu  268030       Indonesia
# 2             MW           Tofua  243060           Tonga
# 3             MW  Montagu Island  390081  United Kingdom
# 4             MW         Bulusan  273010     Philippines
#
#                     Region               Type  Activity Evidence  \
# 0  Japan, Taiwan, Marianas          Submarine     Eruption Dated
# 1                Indonesia      Stratovolcano  Eruption Observed
# 2      New Zealand to Fiji            Caldera  Eruption Observed
# 3               Antarctica             Shield  Eruption Observed
# 4  Philippines and SE Asia  Stratovolcano(es)  Eruption Observed
#
#    Last Known Eruption  Latitude_y  Longitude_y  Elevation (Meters)  \
# 0                 1989      20.130      145.100                  -8
# 1                 2016       1.488      127.630                1325
# 2                 2014     -19.750     -175.070                 515
# 3                 2007     -58.445      -26.374                1370
# 4                 2016      12.770      124.050                1565
#
#              Dominant Rock Type                              Tectonic Setting
# 0  Andesite / Basaltic Andesite     Subduction Zone / Crust Thickness Unknown
# 1  Andesite / Basaltic Andesite     Subduction Zone / Oceanic Crust (< 15 km)
# 2  Andesite / Basaltic Andesite     Subduction Zone / Oceanic Crust (< 15 km)
# 3         Basalt / Picro-Basalt     Subduction Zone / Oceanic Crust (< 15 km)
# 4  Andesite / Basaltic Andesite  Subduction Zone / Continental Crust (>25 km)

# %% [markdown]
# ### Getting Distances
# We are going to use the Haversine formula to get the distances. <br/>
# <br/>
# The Haversine formula is perhaps the first equation to consider when understanding how to calculate distances on a sphere. The word "Haversine" comes from the function:<br/>
# <br/>
# haversine(θ) = sin²(θ/2)<br/>
# <br/>
# The following equation where φ is latitude, λ is longitude, R is earth’s radius (mean radius = 6,371km) is how we translate the above formula to include latitude and longitude coordinates. Note that angles need to be in radians to pass to trig functions:<br/>
# <br/>
# a = sin²(φB - φA/2) + cos φA * cos φB * sin²(λB - λA/2)<br/>
# c = 2 * atan2( √a, √(1−a) )<br/>
# d = R ⋅ c<br/>
# <br/>
#
# [source](https://community.esri.com/groups/coordinate-reference-systems/blog/2017/10/05/haversine-formula)

# %%
# step 1 : get lat & lon radians
rad_lat_eq = np.radians(main_df['Latitude_x'])
rad_lon_eq = np.radians(main_df['Longitude_x'])
rad_lat_ve = np.radians(main_df['Latitude_y'])
rad_lon_ve = np.radians(main_df['Longitude_y'])

# step 2 : get the differences from lat and lon radians
d_rad_lat = (rad_lat_ve - rad_lat_eq)
d_rad_lon = (rad_lon_ve - rad_lon_eq)

# step 3 : use the haversine formula on lat and lon
a = np.sin(d_rad_lat/2)**2 + np.cos(rad_lat_eq) * np.cos(rad_lat_ve) * np.sin(d_rad_lon / 2)**2
c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
d = 6371 * c

# %%
# append the distances to the main dataframes
main_df['Eq - Ve Distances'] = d

# %%
main_df.head()
# Out:
#              Date_Time  Latitude_x  Longitude_x  Depth  Magnitude  \
# 0  1965-01-02 13:44:18      19.246      145.616  131.6        6.0
# 1  1965-01-04 11:29:49       1.863      127.352   80.0        5.8
# 2  1965-01-05 18:05:58     -20.579     -173.972   20.0        6.2
# 3  1965-01-08 18:49:43     -59.076      -23.557   15.0        5.8
# 4  1965-01-09 13:32:50      11.938      126.427   15.0        5.8
#
#   Magnitude Type Nearest Volcano  Number         Country  \
# 0             MW     Supply Reef  284142   United States
# 1             MW             Ibu  268030       Indonesia
# 2             MW           Tofua  243060           Tonga
# 3             MW  Montagu Island  390081  United Kingdom
# 4             MW         Bulusan  273010     Philippines
#
#                     Region               Type  Activity Evidence  \
# 0  Japan, Taiwan, Marianas          Submarine     Eruption Dated
# 1                Indonesia      Stratovolcano  Eruption Observed
# 2      New Zealand to Fiji            Caldera  Eruption Observed
# 3               Antarctica             Shield  Eruption Observed
# 4  Philippines and SE Asia  Stratovolcano(es)  Eruption Observed
#
#    Last Known Eruption  Latitude_y  Longitude_y  Elevation (Meters)  \
# 0                 1989      20.130      145.100                  -8
# 1                 2016       1.488      127.630                1325
# 2                 2014     -19.750     -175.070                 515
# 3                 2007     -58.445      -26.374                1370
# 4                 2016      12.770      124.050                1565
#
#              Dominant Rock Type                              Tectonic Setting  \
# 0  Andesite / Basaltic Andesite     Subduction Zone / Crust Thickness Unknown
# 1  Andesite / Basaltic Andesite     Subduction Zone / Oceanic Crust (< 15 km)
# 2  Andesite / Basaltic Andesite     Subduction Zone / Oceanic Crust (< 15 km)
# 3         Basalt / Picro-Basalt     Subduction Zone / Oceanic Crust (< 15 km)
# 4  Andesite / Basaltic Andesite  Subduction Zone / Continental Crust (>25 km)
#
#    Eq - Ve Distances
# 0         112.162847
# 1          51.898694
# 2         147.078303
# 3         176.936371
# 4         274.261200

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30230 entries, 0 to 30229
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date_Time            30230 non-null  object
#  1   Latitude_x           30230 non-null  float64
#  2   Longitude_x          30230 non-null  float64
#  3   Depth                30230 non-null  float64
#  4   Magnitude            30230 non-null  float64
#  5   Magnitude Type       30230 non-null  object
#  6   Nearest Volcano      30230 non-null  object
#  7   Number               30230 non-null  int64
#  8   Country              30230 non-null  object
#  9   Region               30230 non-null  object
#  10  Type                 30230 non-null  object
#  11  Activity Evidence    30230 non-null  object
#  12  Last Known Eruption  30230 non-null  int64
#  13  Latitude_y           30230 non-null  float64
#  14  Longitude_y          30230 non-null  float64
#  15  Elevation (Meters)   30230 non-null  int64
#  16  Dominant Rock Type   30230 non-null  object
#  17  Tectonic Setting     30230 non-null  object
#  18  Eq - Ve Distances    30230 non-null  float64
# dtypes: float64(7), int64(3), object(9)
# memory usage: 4.6+ MB

# %% [markdown]
# ### Get Year Distances

# %%
main_df['Date_Time'] = pd.to_datetime(main_df['Date_Time'])
main_df['eq_year'] = main_df['Date_Time'].dt.year

# %%
main_df['year_diff'] = main_df['Last Known Eruption'] - main_df['eq_year']

# %%
main_df.sample(10)
# Out:
#                 Date_Time  Latitude_x  Longitude_x  Depth  Magnitude  \
# 25833 2010-03-01 02:44:42    -35.0390     -72.4870   22.9        5.7
# 7792  1983-01-03 06:04:02    -59.4950     -26.2620   45.0        5.5
# 28183 2013-08-04 03:28:51     38.2133     141.8621   56.0        5.8
# 5845  1978-05-30 20:17:15     11.0500      57.3270   33.0        5.5
# 3699  1974-05-10 08:12:05     -4.3720    -102.1090   33.0        6.1
# 13999 1992-08-01 18:19:03    -21.3440    -179.1890  633.9        5.8
# 22467 2005-04-11 11:11:01      8.6600    -103.5640   10.0        5.5
# 25998 2010-06-26 09:50:43     -8.0700     108.0890   68.0        5.9
# 24275 2007-11-26 17:41:41     15.2800     -93.3630   87.2        5.7
# 27021 2011-08-21 00:23:40    -18.2400     167.8670   35.0        5.6
#
#       Magnitude Type Nearest Volcano  Number            Country  \
# 25833            MWB     Azul, Cerro  353060            Ecuador
# 7792              MB  Bristol Island  390080     United Kingdom
# 28183            MWW     Adatarayama  283170              Japan
# 5845              MS       Ardoukoba  221126           Djibouti
# 3699              MB         Unnamed  385052  Undersea Features
# 13999             MW         Unnamed  250030   Papua New Guinea
# 22467            MWC         Unnamed  334040  Undersea Features
# 25998            MWC      Galunggung  263140          Indonesia
# 24275            MWC          Tacana  341130   Mexico-Guatemala
# 27021            MWB           Kuwae  257070            Vanuatu
#
#                            Region               Type  Activity Evidence  \
# 25833               South America             Shield  Eruption Observed
# 7792                   Antarctica      Stratovolcano  Eruption Observed
# 28183     Japan, Taiwan, Marianas  Stratovolcano(es)  Eruption Observed
# 5845           Africa and Red Sea    Fissure vent(s)  Eruption Observed
# 3699               Atlantic Ocean          Submarine  Eruption Observed
# 13999     Melanesia and Australia          Submarine     Eruption Dated
# 22467    Hawaii and Pacific Ocean          Submarine  Eruption Observed
# 25998                   Indonesia      Stratovolcano  Eruption Observed
# 24275  México and Central America      Stratovolcano  Eruption Observed
# 27021     Melanesia and Australia            Caldera  Eruption Observed
#
#        Last Known Eruption  Latitude_y  Longitude_y  Elevation (Meters)  \
# 25833                 2008      -0.920      -91.408                1640
# 7792                  2016     -59.017      -26.533                1100
# 28183                 1996      37.647      140.281                1728
# 5845                  1978      11.580       42.470                 298
# 3699                  2002     -32.958       -5.220                   0
# 13999                 1972      -3.030      147.780               -1300
# 22467                 2003      10.730     -103.580                   0
# 25998                 1984      -7.250      108.058                2168
# 24275                 1986      15.132      -92.109                4064
# 27021                 1974     -16.829      168.536                  -2
#
#                  Dominant Rock Type  \
# 25833         Basalt / Picro-Basalt
# 7792          Basalt / Picro-Basalt
# 28183  Andesite / Basaltic Andesite
# 5845          Basalt / Picro-Basalt
# 3699          Basalt / Picro-Basalt
# 13999         Basalt / Picro-Basalt
# 22467         Basalt / Picro-Basalt
# 25998         Basalt / Picro-Basalt
# 24275  Andesite / Basaltic Andesite
# 27021         Basalt / Picro-Basalt
#
#                                       Tectonic Setting  Eq - Ve Distances  \
# 25833              Rift Zone / Oceanic Crust (< 15 km)        4270.437646
# 7792         Subduction Zone / Oceanic Crust (< 15 km)          55.338348
# 28183     Subduction Zone / Continental Crust (>25 km)         152.296665
# 5845         Rift Zone / Intermediate Crust (15-25 km)        1620.802656
# 3699              Intraplate / Oceanic Crust (< 15 km)       10382.875163
# 13999           Rift Zone / Continental Crust (>25 km)        4110.135662
# 22467             Intraplate / Oceanic Crust (< 15 km)         230.180178
# 25998     Subduction Zone / Continental Crust (>25 km)          91.243816
# 24275     Subduction Zone / Continental Crust (>25 km)         135.558971
# 27021  Subduction Zone / Intermediate Crust (15-25 km)         172.184541
#
#        eq_year  year_diff
# 25833     2010         -2
# 7792      1983         33
# 28183     2013        -17
# 5845      1978          0
# 3699      1974         28
# 13999     1992        -20
# 22467     2005         -2
# 25998     2010        -26
# 24275     2007        -21
# 27021     2011        -37

# %% [markdown]
# ## Create a Target Column
# The target of this project is to predict wether an earthquake is related to volcanic eruption and it follows with this question:<br/>
# #### Can earthquakes trigger volcanic eruptions?
# and the answer is yes given a few given parameters. earthquake with a large magnitude (greater than 6) are considered to be related to a subsequent eruption or to some type of unrest at a nearby volcano. However, volcanoes can only be triggered into eruption by nearby tectonic earthquakes if they are already poised to erupt.[[1]](https://www.usgs.gov/faqs/can-earthquakes-trigger-volcanic-eruptions?qt-news_science_products=0#qt-news_science_products) Therefore I conclude the parameters: <br/>
# 1. Magnitude greater than 6
# 2. Distances less than ~Q1 (500 Km)
# 3. Earthquake happened before the eruption
# <br/>
# <br/>
# It should be noted that these parameters were not 100% accurate given at a time it is still debatable. however this parameter should give enough to forecast wether or not an earthquake has a potential to trigger volcanic eruption.

# %%
def potential_eruption(main_df):

    if (main_df['Magnitude'] > 6) and (main_df['Eq - Ve Distances'] <= 500) and (main_df['year_diff'] > 0):
        return 1
    else :
        return 0
main_df['potential_eruption'] = main_df.apply(potential_eruption, axis = 1)

# %%
main_df.columns
# Out:
# Index(['Date_Time', 'Latitude_x', 'Longitude_x', 'Depth', 'Magnitude',
#        'Magnitude Type', 'Nearest Volcano', 'Number', 'Country', 'Region',
#        'Type', 'Activity Evidence', 'Last Known Eruption', 'Latitude_y',
#        'Longitude_y', 'Elevation (Meters)', 'Dominant Rock Type',
#        'Tectonic Setting', 'Eq - Ve Distances', 'eq_year', 'year_diff',
#        'potential_eruption'],
#       dtype='object')

# %%
main_df = main_df[['Date_Time', 'eq_year', 'Latitude_x', 'Longitude_x', 'Depth', 'Magnitude',
       'Magnitude Type', 'Nearest Volcano', 'Number', 'Country', 'Region',
       'Type', 'Activity Evidence', 'Last Known Eruption', 'Latitude_y',
       'Longitude_y', 'Elevation (Meters)', 'Dominant Rock Type',
       'Tectonic Setting', 'Eq - Ve Distances', 'year_diff',
       'potential_eruption']]

# %%
main_df = main_df.rename(columns = {'Date_Time' : 'eq_date_time','Latitude_x' : 'eq_lat',
                                   'Longitude_x' : 'eq_lon','Depth' : 'eq_depth','Magnitude' : 'eq_mag',
                                   'Magnitude Type' : 'eq_mag_type','Nearest Volcano' : 've_closest',
                                   'Country' : 've_country','Region' : 've_region','Type' : 've_type',
                                   'Activity Evidence' : 've_evidence','Last Known Eruption':'ve_year',
                                   'Latitude_y' : 've_lat','Longitude_y' : 've_lon','Elevation (Meters)':'ve_ele',
                                   'Dominant Rock Type' : 've_rock','Tectonic Setting':'ve_tect','Eq - Ve Distances':'eq_ve_dist',
                                   'year_diff':'eq_ve_yeardiff'})
main_df = main_df.drop('Number', axis = 1)

# %%
main_df.head()
# Out:
#          eq_date_time  eq_year  eq_lat   eq_lon  eq_depth  eq_mag eq_mag_type  \
# 0 1965-01-02 13:44:18     1965  19.246  145.616     131.6     6.0          MW
# 1 1965-01-04 11:29:49     1965   1.863  127.352      80.0     5.8          MW
# 2 1965-01-05 18:05:58     1965 -20.579 -173.972      20.0     6.2          MW
# 3 1965-01-08 18:49:43     1965 -59.076  -23.557      15.0     5.8          MW
# 4 1965-01-09 13:32:50     1965  11.938  126.427      15.0     5.8          MW
#
#        ve_closest      ve_country                ve_region            ve_type  \
# 0     Supply Reef   United States  Japan, Taiwan, Marianas          Submarine
# 1             Ibu       Indonesia                Indonesia      Stratovolcano
# 2           Tofua           Tonga      New Zealand to Fiji            Caldera
# 3  Montagu Island  United Kingdom               Antarctica             Shield
# 4         Bulusan     Philippines  Philippines and SE Asia  Stratovolcano(es)
#
#          ve_evidence  ve_year  ve_lat   ve_lon  ve_ele  \
# 0     Eruption Dated     1989  20.130  145.100      -8
# 1  Eruption Observed     2016   1.488  127.630    1325
# 2  Eruption Observed     2014 -19.750 -175.070     515
# 3  Eruption Observed     2007 -58.445  -26.374    1370
# 4  Eruption Observed     2016  12.770  124.050    1565
#
#                         ve_rock                                       ve_tect  \
# 0  Andesite / Basaltic Andesite     Subduction Zone / Crust Thickness Unknown
# 1  Andesite / Basaltic Andesite     Subduction Zone / Oceanic Crust (< 15 km)
# 2  Andesite / Basaltic Andesite     Subduction Zone / Oceanic Crust (< 15 km)
# 3         Basalt / Picro-Basalt     Subduction Zone / Oceanic Crust (< 15 km)
# 4  Andesite / Basaltic Andesite  Subduction Zone / Continental Crust (>25 km)
#
#    eq_ve_dist  eq_ve_yeardiff  potential_eruption
# 0  112.162847              24                   0
# 1   51.898694              51                   0
# 2  147.078303              49                   1
# 3  176.936371              42                   0
# 4  274.261200              51                   0

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30230 entries, 0 to 30229
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   eq_date_time        30230 non-null  datetime64[ns]
#  1   eq_year             30230 non-null  int64
#  2   eq_lat              30230 non-null  float64
#  3   eq_lon              30230 non-null  float64
#  4   eq_depth            30230 non-null  float64
#  5   eq_mag              30230 non-null  float64
#  6   eq_mag_type         30230 non-null  object
#  7   ve_closest          30230 non-null  object
#  8   ve_country          30230 non-null  object
#  9   ve_region           30230 non-null  object
#  10  ve_type             30230 non-null  object
#  11  ve_evidence         30230 non-null  object
#  12  ve_year             30230 non-null  int64
#  13  ve_lat              30230 non-null  float64
#  14  ve_lon              30230 non-null  float64
#  15  ve_ele              30230 non-null  int64
#  16  ve_rock             30230 non-null  object
#  17  ve_tect             30230 non-null  object
#  18  eq_ve_dist          30230 non-null  float64
#  19  eq_ve_yeardiff      30230 non-null  int64
#  20  potential_eruption  30230 non-null  int64
# dtypes: datetime64[ns](1), float64(7), int64(5), object(8)
# memory usage: 5.1+ MB

# %%
main_df.describe()
# Out:
#             eq_year        eq_lat        eq_lon      eq_depth        eq_mag  \
# count  30230.000000  30230.000000  30230.000000  30230.000000  30230.000000
# mean    1992.971783     -1.449964      7.099548     99.919419      5.867285
# std       14.181014     28.627924    138.221946    167.645712      0.413053
# min     1965.000000    -77.080000   -179.997000     -1.100000      5.500000
# 25%     1982.000000    -21.052750   -157.680250     15.000000      5.600000
# 50%     1994.000000     -6.109500     45.269000     33.000000      5.700000
# 75%     2005.000000     17.012750    143.006750     71.900000      6.000000
# max     2016.000000     86.005000    179.998000    700.000000      9.100000
#
#             ve_year        ve_lat        ve_lon        ve_ele    eq_ve_dist  \
# count  30230.000000  30230.000000  30230.000000  30230.000000  30230.000000
# mean    1999.300430      0.682569     21.558359    790.439795   2279.512565
# std       15.705822     27.654128    129.419123   1856.504976   3840.048637
# min     1966.000000    -77.530000   -179.033000  -4100.000000      0.702917
# 25%     1989.000000    -18.325000   -104.300000    -39.000000    127.549367
# 50%     2003.000000     -3.520000     77.825000    516.000000    305.715502
# 75%     2014.000000     14.950000    145.800000   1728.000000   2186.886433
# max     2016.000000     85.608000    179.580000   5967.000000  17882.797816
#
#        eq_ve_yeardiff  potential_eruption
# count    30230.000000        30230.000000
# mean         6.328647            0.099669
# std         21.377995            0.299563
# min        -50.000000            0.000000
# 25%         -8.000000            0.000000
# 50%          7.000000            0.000000
# 75%         22.000000            0.000000
# max         51.000000            1.000000

# %%
main_df.to_csv('./data/merged_earthquake_volcano.csv', index = False)
